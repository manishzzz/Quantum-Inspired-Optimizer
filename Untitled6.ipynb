# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %run /content/drive/MyDrive/QIHO/run_pneumonia_qiho.py
# Out:
# Using device: cuda
# Loading dataset...
# Total images found: 5216
# Train size: 4172, Val size: 1044
# Starting optimization script...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /content/drive/MyDrive/QIHO/run_pneumonia_qiho.py in <module>
#     114     ]
#     115
# --> 116     optimizer = QIHO_GodKiller(
#     117         obj_func=objective_function,
#     118         dim=3,
#
# TypeError: QIHO_GodKiller.__init__() got an unexpected keyword argument 'obj_func'

# %%
# %run /content/drive/MyDrive/QIHO/finance_credit.py
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /content/drive/MyDrive/QIHO/finance_credit.py in <module>
#      11
#      12 # Load dataset
# ---> 13 df = pd.read_csv("content/drive/MyDrive/QIHO/credit_data.csv")
#      14
#      15 # Drop ID column and split features/target
#
# ...

# %%
# %run /content/drive/MyDrive/QIHO/run_finance.py
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /content/drive/MyDrive/QIHO/run_finance.py in <module>
#       2
#       3 from core_v13 import QIHO_GodKiller
# ----> 4 from finance_credit import objective_function
#       5 from utils import plot_convergence
#       6
#
# /content/drive/MyDrive/QIHO/finance_credit.py in <module>
#      11
#      12 # Load dataset
# ---> 13 df = pd.read_csv("content/drive/MyDrive/QIHO/credit_data.csv")
#      14
#      15 # Drop ID column and split features/target
#
# ...
